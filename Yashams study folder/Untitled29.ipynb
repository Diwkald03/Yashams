# %% [markdown]
# #13 July, 2025

# %% [markdown]
# ### 1. Create a variable name & assign your name to it. Print the variable

# %%
name= 'Yash'
print(name)
# Out:
# Yash

# %% [markdown]
# #### 2. Declare 2 variables a & b, assign them integer values, and print their sum

# %%
a=24
b=21
a+b
# Out:
# 45

# %% [markdown]
# #### 3. Assign a floating - point number to a variable price and prints its value

# %%
Price=45.3
Price
# Out:
# 45.3

# %% [markdown]
# ####4. Declare a boolean variable Is_Valid with the value True and print it

# %%
Is_Valid= True
Is_Valid
# Out:
# True

# %% [markdown]
# ### 5. Create 3 variables X, Y, Z & assign them the values 10, 20, 30 in a single line. Print them

# %%
X=10
Y=20
Z=30
X, Y, Z
# Out:
# (10, 20, 30)

# %% [markdown]
# ### 6. Assign the same value 100 to three variables P, Q, R an print them

# %%
P=100
Q=100
R=100
P, Q, R
# Out:
# (100, 100, 100)

# %% [markdown]
# ###7. Change the value of variable age from 25 to 30 and print both values

# %%
age = 25
print(f"Initial age: {age}")
age = 30
print(f"New age: {age}")
# Out:
# Initial age: 25
# New age: 30

# %% [markdown]
# ### 8. Assign a value to a variable, delete it using del, & try to print it

# %%
x=20
del x
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-667912645.py in <cell line: 0>()
#       1 x=20
#       2 del x
# ----> 3 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### 9. Create a vsriable a Message, assign a string to it, & print its length using len()

# %%
Message='Hello Sams'
len(Message)
# Out:
# 10

# %% [markdown]
# ### 10. Declare a variable data, assign an integer value, chance it to a string, & print both values

# %%
data = 20
print(f"Original integer value: {data}")

data1 = str(data)
print(f"Converted string value: {data1}")
# Out:
# Original integer value: 20
# Converted string value: 20
