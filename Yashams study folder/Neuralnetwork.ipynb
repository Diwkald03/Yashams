# %%
from sklearn.neural_network import MLPClassifier

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[5]]))
# Out:
# [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[6]]))
# Out:
# [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[3]]))
# Out:
# [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[1]]))
# Out:
# [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[2]]))
# Out:
# [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
X = [[1] , [2] , [3], [4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[4]]))
# Out:
# [0]

# %%
X = [[1],[2],[3],[4],[5],[6],[7],[8]]
y = [1,0,1,0,1,0,1,0]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[1]]))
# Out:
# [1]

# %%
X = [[1],[2],[3],[4],[5],[6],[7],[8]]
y = [1,0,1,0,1,0,1,0]

model = MLPClassifier(max_iter=5000, random_state=1)
model.fit(X,y)

print(model.predict([[3]]))
# Out:
# [0]

# %%
from sklearn.preprocessing import StandardScaler

X = [[1],[2],[3],[4],[5],[6],[7],[8]]
y = [1,0,1,0,1,0,1,0]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
model = MLPClassifier(hidden_layer_sizes=(5,),max_iter=5000, random_state=1)
model.fit(X_scaled,y)

print(model.predict([[1]]))
# Out:
# [1]

# %%
from sklearn.linear_model import LogisticRegression

X = [[1],[2],[3],[4],[5],[6],[7],[8]]
y = [1,0,1,0,1,0,1,0]

model1 = LogisticRegression()
model1.fit(X,y)

print(model1.predict([[0]]))
# Out:
# [1]

# %%
from sklearn.linear_model import LogisticRegression

X = [[30],[40],[50],[60]]
y = [0,0,1,1]

model1 = LogisticRegression()
model1.fit(X,y)

print(model1.predict([[80]]))
# Out:
# [1]

# %%
X = [[30],[40],[50],[60]]
y = [0,0,1,1]

model = MLPClassifier(max_iter=1000)
model.fit(X,y)

print(model.predict([[30]]))
# Out:
# [1]

# %%
X = [[30],[40],[50],[60]]
y = [0,0,1,1]

model = MLPClassifier(max_iter=5000)
model.fit(X,y)

print(model.predict([[41]]))
# Out:
# [1]

# %%
X = [[1],[2],[3],[4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=5000)
model.fit(X,y)

print(model.predict([[3]]))
# Out:
# [1]

# %%
X = [[1],[2],[3],[4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=5000)
model.fit(X,y)

print(model.predict([[4]]))
# Out:
# [0]

# %%
X = [[1],[2],[3],[4]]
y = [1,0,1,0]

model = MLPClassifier(max_iter=10000)
model.fit(X,y)

print(model.predict([[3]]))
# Out:
# [1]

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

X=np.array([[1],[2],[3],[4]],dtype=float)
y = np.array([0,0,1,1], dtype=float)

model = Sequential()
model.add(Dense(1,input_shape=(1,),activation="sigmoid"))

model.compile(optimizer="adam",loss="binary_crossentropy")
model.fit(X,y,epochs=50,verbose=0)

print(model.predict(np.array([[1.1]]), verbose=0))
print(model.predict(np.array([[4.0]]), verbose=0))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [[0.6184803]]
# [[0.8684077]]

# %%
from keras.models import Sequential as sequential
from keras.layers import Dense, Input
import numpy as np

x = np.array([[1], [2], [3], [4]], dtype=float)
y = np.array([0, 0, 1, 1], dtype=float)

model = sequential()
model.add(Dense(1,input_shape=(1,),activation='sigmoid'))

model.compile(optimizer='adam',loss="binary_crossentropy")
model.fit(x, y, epochs=50, verbose=0)


print(model.predict(np.array([[1.1]]), verbose=0))
print(model.predict(np.array([[4.0]]), verbose=0))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [[0.3364646]]
# [[0.06912331]]
