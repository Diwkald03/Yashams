# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1sgMbcgoOGEDSWu3MDrIcoADW59HZU4ujoLgNBUZJVXg/export?format=csv"
data = pd.read_csv(url)

display(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
selected_data = data[["FIRST_NAME", "LAST_NAME","EMAIL"]]
print(selected_data)
# Out:
#      FIRST_NAME    LAST_NAME     EMAIL
# 0        Donald     OConnell  DOCONNEL
# 1       Douglas        Grant    DGRANT
# 2      Jennifer       Whalen   JWHALEN
# 3       Michael    Hartstein  MHARTSTE
# 4           Pat          Fay      PFAY
# 5         Susan       Mavris   SMAVRIS
# 6       Hermann         Baer     HBAER
# 7       Shelley      Higgins  SHIGGINS
# 8       William        Gietz    WGIETZ
# 9        Steven         King     SKING
# 10        Neena      Kochhar  NKOCHHAR
# 11          Lex      De Haan   LDEHAAN
# 12    Alexander       Hunold   AHUNOLD
# 13        Bruce        Ernst    BERNST
# 14        David       Austin   DAUSTIN
# 15        Valli    Pataballa  VPATABAL
# 16        Diana      Lorentz  DLORENTZ
# 17        Nancy    Greenberg  NGREENBE
# 18       Daniel       Faviet   DFAVIET
# 19         John         Chen     JCHEN
# 20       Ismael      Sciarra  ISCIARRA
# 21  Jose Manuel        Urman   JMURMAN
# 22         Luis         Popp     LPOPP
# ...

# %%
data.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
selected_data = data[["FIRST_NAME", "LAST_NAME","EMAIL"]]
display(selected_data)
# Out:
#      FIRST_NAME    LAST_NAME     EMAIL
# 0        Donald     OConnell  DOCONNEL
# 1       Douglas        Grant    DGRANT
# 2      Jennifer       Whalen   JWHALEN
# 3       Michael    Hartstein  MHARTSTE
# 4           Pat          Fay      PFAY
# 5         Susan       Mavris   SMAVRIS
# 6       Hermann         Baer     HBAER
# 7       Shelley      Higgins  SHIGGINS
# 8       William        Gietz    WGIETZ
# 9        Steven         King     SKING
# 10        Neena      Kochhar  NKOCHHAR
# 11          Lex      De Haan   LDEHAAN
# 12    Alexander       Hunold   AHUNOLD
# 13        Bruce        Ernst    BERNST
# 14        David       Austin   DAUSTIN
# 15        Valli    Pataballa  VPATABAL
# 16        Diana      Lorentz  DLORENTZ
# 17        Nancy    Greenberg  NGREENBE
# 18       Daniel       Faviet   DFAVIET
# 19         John         Chen     JCHEN
# 20       Ismael      Sciarra  ISCIARRA
# 21  Jose Manuel        Urman   JMURMAN
# 22         Luis         Popp     LPOPP
# ...

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1sgMbcgoOGEDSWu3MDrIcoADW59HZU4ujoLgNBUZJVXg/export?format=csv"
data = pd.read_csv(url)

display(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
data.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600              -        124             50
# 1  SH_CLERK    2600              -        124             50
# 2   AD_ASST    4400              -        101             10
# 3    MK_MAN   13000              -        100             20
# 4    MK_REP    6000              -        201             20

# %%
data.head(10)
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
# 5          203      Susan     Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6          204    Hermann       Baer     HBAER  515.123.8888  07-Jun-02
# 7          205    Shelley    Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8          206    William      Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9          100     Steven       King     SKING  515.123.4567  17-Jun-03
#
#        JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0    SH_CLERK    2600              -        124             50
# ...

# %%
data.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
df=data.copy()

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df['EMAIL'].str.lower()
# Out:
# 0     doconnel
# 1       dgrant
# 2      jwhalen
# 3     mhartste
# 4         pfay
# 5      smavris
# 6        hbaer
# 7     shiggins
# 8       wgietz
# 9        sking
# 10    nkochhar
# 11     ldehaan
# 12     ahunold
# 13      bernst
# 14     daustin
# 15    vpatabal
# 16    dlorentz
# 17    ngreenbe
# 18     dfaviet
# 19       jchen
# 20    isciarra
# 21     jmurman
# 22       lpopp
# 23    drapheal
# 24       akhoo
# 25      sbaida
# 26     stobias
# 27     ghimuro
# 28    kcolmena
# 29      mweiss
# 30      afripp
# 31    pkauflin
# 32    svollman
# 33    kmourgos
# 34      jnayer
# 35    imikkili
# 36     jlandry
# 37     smarkle
# 38     lbissot
# 39    matkinso
# 40     jamrlow
# 41     tjolson
# 42     jmallin
# 43     mrogers
# 44        kgee
# 45    hphiltan
# 46     rladwig
# 47     sstiles
# 48        jseo
# 49      jpatel
# Name: EMAIL, dtype: object

# %%
columns = data.columns.str.capitalize()

# %%
df=data.copy()

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600              -        124             50
# 1  SH_CLERK    2600              -        124             50
# 2   AD_ASST    4400              -        101             10
# 3    MK_MAN   13000              -        100             20
# 4    MK_REP    6000              -        201             20

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df=df['EMAIL'].str.lower()

# %%
df.head()
# Out:
# 0    doconnel
# 1      dgrant
# 2     jwhalen
# 3    mhartste
# 4        pfay
# Name: EMAIL, dtype: object

# %%
df
# Out:
# 0     doconnel
# 1       dgrant
# 2      jwhalen
# 3     mhartste
# 4         pfay
# 5      smavris
# 6        hbaer
# 7     shiggins
# 8       wgietz
# 9        sking
# 10    nkochhar
# 11     ldehaan
# 12     ahunold
# 13      bernst
# 14     daustin
# 15    vpatabal
# 16    dlorentz
# 17    ngreenbe
# 18     dfaviet
# 19       jchen
# 20    isciarra
# 21     jmurman
# 22       lpopp
# 23    drapheal
# 24       akhoo
# 25      sbaida
# 26     stobias
# 27     ghimuro
# 28    kcolmena
# 29      mweiss
# 30      afripp
# 31    pkauflin
# 32    svollman
# 33    kmourgos
# 34      jnayer
# 35    imikkili
# 36     jlandry
# 37     smarkle
# 38     lbissot
# 39    matkinso
# 40     jamrlow
# 41     tjolson
# 42     jmallin
# 43     mrogers
# 44        kgee
# 45    hphiltan
# 46     rladwig
# 47     sstiles
# 48        jseo
# 49      jpatel
# Name: EMAIL, dtype: object

# %%
data
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df = data.copy()

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df = data.copy() # Re-initialize df as a DataFrame
df['EMAIL'] = df['EMAIL'].str.lower()
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  doconnel  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    dgrant  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   jwhalen  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  mhartste  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      pfay  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   smavris  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     hbaer  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  shiggins  515.123.8080  07-Jun-02
# 8           206      William        Gietz    wgietz  515.123.8181  07-Jun-02
# 9           100       Steven         King     sking  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  nkochhar  515.123.4568  21-Sep-05
# ...

# %%
df['EMAIL'] = df['EMAIL'].str.lower()
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  doconnel  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    dgrant  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   jwhalen  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  mhartste  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      pfay  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   smavris  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     hbaer  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  shiggins  515.123.8080  07-Jun-02
# 8           206      William        Gietz    wgietz  515.123.8181  07-Jun-02
# 9           100       Steven         King     sking  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  nkochhar  515.123.4568  21-Sep-05
# ...

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  doconnel  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    dgrant  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   jwhalen  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  mhartste  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      pfay  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   smavris  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     hbaer  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  shiggins  515.123.8080  07-Jun-02
# 8           206      William        Gietz    wgietz  515.123.8181  07-Jun-02
# 9           100       Steven         King     sking  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  nkochhar  515.123.4568  21-Sep-05
# ...

# %%
df = data.copy()
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600              -        124             50
# 1  SH_CLERK    2600              -        124             50
# 2   AD_ASST    4400              -        101             10
# 3    MK_MAN   13000              -        100             20
# 4    MK_REP    6000              -        201             20

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600              -        124             50
# 1  SH_CLERK    2600              -        124             50
# 2   AD_ASST    4400              -        101             10
# 3    MK_MAN   13000              -        100             20
# 4    MK_REP    6000              -        201             20

# %%
df[df["FIRST_NAME"].str.startswith("D")]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198     Donald  OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199    Douglas     Grant    DGRANT  650.507.9844  13-Jan-08
# 14          105      David    Austin   DAUSTIN  590.423.4569  25-Jun-05
# 16          107      Diana   Lorentz  DLORENTZ  590.423.5567  07-Feb-07
# 18          109     Daniel    Faviet   DFAVIET  515.124.4169  16-Aug-02
# 23          114        Den  Raphaely  DRAPHEAL  515.127.4561  07-Dec-02
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0     SH_CLERK    2600              -        124             50
# 1     SH_CLERK    2600              -        124             50
# 14     IT_PROG    4800              -        103             60
# 16     IT_PROG    4200              -        103             60
# 18  FI_ACCOUNT    9000              -        108            100
# 23      PU_MAN   11000              -        100             30

# %%
df['FULL NAME'] = df['FIRST_NAME'] + ' ' + df['LAST_NAME']
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  \
# 0  SH_CLERK    2600              -        124             50
# 1  SH_CLERK    2600              -        124             50
# 2   AD_ASST    4400              -        101             10
# 3    MK_MAN   13000              -        100             20
# 4    MK_REP    6000              -        201             20
#
#            FULL NAME
# 0    Donald OConnell
# 1      Douglas Grant
# 2    Jennifer Whalen
# 3  Michael Hartstein
# 4            Pat Fay

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
data = data[data['FIRST_NAME'] != 'Donald']
display(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# 11          102          Lex      De Haan   LDEHAAN  515.123.4569  13-Jan-01
# ...

# %%
df1 = df.copy()

# %%
df1=df1[['LAST_NAME','FIRST_NAME']]

# %%
df1
# Out:
#       LAST_NAME   FIRST_NAME
# 0      OConnell       Donald
# 1         Grant      Douglas
# 2        Whalen     Jennifer
# 3     Hartstein      Michael
# 4           Fay          Pat
# 5        Mavris        Susan
# 6          Baer      Hermann
# 7       Higgins      Shelley
# 8         Gietz      William
# 9          King       Steven
# 10      Kochhar        Neena
# 11      De Haan          Lex
# 12       Hunold    Alexander
# 13        Ernst        Bruce
# 14       Austin        David
# 15    Pataballa        Valli
# 16      Lorentz        Diana
# 17    Greenberg        Nancy
# 18       Faviet       Daniel
# 19         Chen         John
# 20      Sciarra       Ismael
# 21        Urman  Jose Manuel
# 22         Popp         Luis
# 23     Raphaely          Den
# 24         Khoo    Alexander
# 25        Baida       Shelli
# 26       Tobias        Sigal
# 27       Himuro          Guy
# 28   Colmenares        Karen
# 29        Weiss      Matthew
# 30        Fripp         Adam
# ...

# %%
df1.head(3)
# Out:
#        NAME FIRST_NAME
# 0  OConnell     Donald
# 1     Grant    Douglas
# 2    Whalen   Jennifer

# %%
col=df1.pop('NAME')
df1.insert(0,'F_NAME',col)

# %%
df1
# Out:
#          F_NAME   FIRST_NAME
# 0      OConnell       Donald
# 1         Grant      Douglas
# 2        Whalen     Jennifer
# 3     Hartstein      Michael
# 4           Fay          Pat
# 5        Mavris        Susan
# 6          Baer      Hermann
# 7       Higgins      Shelley
# 8         Gietz      William
# 9          King       Steven
# 10      Kochhar        Neena
# 11      De Haan          Lex
# 12       Hunold    Alexander
# 13        Ernst        Bruce
# 14       Austin        David
# 15    Pataballa        Valli
# 16      Lorentz        Diana
# 17    Greenberg        Nancy
# 18       Faviet       Daniel
# 19         Chen         John
# 20      Sciarra       Ismael
# 21        Urman  Jose Manuel
# 22         Popp         Luis
# 23     Raphaely          Den
# 24         Khoo    Alexander
# 25        Baida       Shelli
# 26       Tobias        Sigal
# 27       Himuro          Guy
# 28   Colmenares        Karen
# 29        Weiss      Matthew
# 30        Fripp         Adam
# ...

# %%
display(df[df['SALARY'] > 10000])
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 9           100     Steven       King     SKING  515.123.4567  17-Jun-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-Jan-01
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-Aug-02
# 23          114        Den   Raphaely  DRAPHEAL  515.127.4561  07-Dec-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  \
# 3    MK_MAN   13000              -        100             20
# 7    AC_MGR   12008              -        101            110
# 9   AD_PRES   24000              -          -             90
# 10    AD_VP   17000              -        100             90
# 11    AD_VP   17000              -        100             90
# ...

# %%
res=len(df[df['SALARY']> 10000])
print("Total employees who has greater than 10k salary:", res)
# Out:
# Total employees who has greater than 10k salary: 7

# %%
df['HIRE_DATE'] = pd.to_datetime(df['HIRE_DATE'])
print(df[df['HIRE_DATE'].dt.year == 2025])
# Out:
# Empty DataFrame
# Columns: [EMPLOYEE_ID, FIRST_NAME, LAST_NAME, EMAIL, PHONE_NUMBER, HIRE_DATE, JOB_ID, SALARY, COMMISSION_PCT, MANAGER_ID, DEPARTMENT_ID, FULL NAME]
# Index: []
# /tmp/ipykernel_225/2418195133.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['HIRE_DATE'] = pd.to_datetime(df['HIRE_DATE'])

# %%
df1 = df[df['HIRE_DATE'].dt.month_name().str.contains('August')]

# %%
df1.head(3)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 4           202        Pat        Fay      PFAY  603.123.6666 2005-08-17
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569 2002-08-17
# 18          109     Daniel     Faviet   DFAVIET  515.124.4169 2002-08-16
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  \
# 4       MK_REP    6000              -        201             20
# 17      FI_MGR   12008              -        101            100
# 18  FI_ACCOUNT    9000              -        108            100
#
#           FULL NAME
# 4           Pat Fay
# 17  Nancy Greenberg
# 18    Daniel Faviet

# %%
df1 = df[df['HIRE_DATE'].dt.year == 2005]

# %%
df1.head(3)
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 4           202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 10          101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 14          105      David    Austin   DAUSTIN  590.423.4569 2005-06-25
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID      FULL NAME
# 4    MK_REP    6000              -        201             20        Pat Fay
# 10    AD_VP   17000              -        100             90  Neena Kochhar
# 14  IT_PROG    4800              -        103             60   David Austin
