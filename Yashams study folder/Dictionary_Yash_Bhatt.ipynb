# %% [markdown]
# #09 August, 2025

# %% [markdown]
# #Task: Dictionary in Python

# %% [markdown]
# ##1. Create a dictionary `student` with keys `"name"`, `"age"`, and `"grade"` and print it.

# %%
student = {"name": "Yash", "age": 25, "grade": "A"}

print(f"Name: {student['name']}")
print(f"Age: {student['age']}")
print(f"Grade: {student['grade']}")
# Out:
# Name: Yash
# Age: 25
# Grade: A

# %% [markdown]
# ##2. Access and print the value of the `"name"` key from the `student` dictionary.

# %%
print(f"Name: {student.get('name')}")
# Out:
# Name: Yash

# %% [markdown]
# ##3. Use the `get()` method to access the `"age"` key safely and print its value.

# %%
print(f"Age: {student.get('age')}")
# Out:
# Age: 25

# %% [markdown]
# ##4. Add a new key-value pair `"city": "Bangalore"` to the `student` dictionary and print the updated dictionary.

# %%
student['city'] = 'Bangalore'

print(f"Name: {student['name']}")
print(f"Age: {student['age']}")
print(f"Grade: {student['grade']}")
print(f"City: {student['city']}")
# Out:
# Name: Yash
# Age: 25
# Grade: A
# City: Bangalore

# %% [markdown]
# ##5. Modify the `"grade"` value in the `student` dictionary to `"A+"` and print the dictionary.

# %%
student['grade'] = 'A+'

print(f"Name: {student['name']}")
print(f"Age: {student['age']}")
print(f"Grade: {student['grade']}")
print(f"City: {student['city']}")
# Out:
# Name: Yash
# Age: 25
# Grade: A+
# City: Bangalore

# %% [markdown]
# ##6. Remove the `"age"` key from the `student` dictionary using `pop()` and print the updated dictionary.

# %%
student.pop('age', None) # Remove 'age' if it exists, otherwise do nothing

print(f"Name: {student['name']}")
print(f"Grade: {student['grade']}")
print(f"City: {student['city']}")
print(f"Age: {student.get('age', 'N/A')}")
# Out:
# Name: Yash
# Grade: A+
# City: Bangalore
# Age: N/A

# %% [markdown]
# ##7. Write a loop to print all keys and values from the `student` dictionary.

# %%
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name: Yash
# grade: A+
# city: Bangalore

# %% [markdown]
# ##8. Check if the key `"email"` exists in the dictionary before accessing it.

# %%
if 'email' in student:
    print(f"Email: {student['email']}")
else:
    print("Email key does not exist in the dictionary")
# Out:
# Email key does not exist in the dictionary

# %% [markdown]
# ##9. Use `clear()` to remove all elements from the dictionary and print it.

# %%
student.clear()
student
# Out:
# {}

# %% [markdown]
# ##10. Create a nested dictionary containing information about multiple students and print details of one student using key access.

# %%
students = {
    "stud1": {
        "name": "Yash",
        "age": 22,
        "grade": "A+",
        "city": "Rajkot"
    },
    "stud2": {
        "name": "Sams",
        "age": 22,
        "grade": "A",
        "city": "Nagpur"
    }
}

print("All Students Information:")
print(students)

print("\nDetails of student2 (using nested key access)")
print(f"Name: {students['stud2']['name']}")
print(f"Age: {students['stud2']['age']}")
print(f"Grade: {students['stud2']['grade']}")
print(f"City: {students['stud2']['city']}")
# Out:
# All Students Information:
# {'stud1': {'name': 'Yash', 'age': 22, 'grade': 'A+', 'city': 'Rajkot'}, 'stud2': {'name': 'Sams', 'age': 22, 'grade': 'A', 'city': 'Nagpur'}}
#
# Details of student2 (using nested key access)
# Name: Sams
# Age: 22
# Grade: A
# City: Nagpur
